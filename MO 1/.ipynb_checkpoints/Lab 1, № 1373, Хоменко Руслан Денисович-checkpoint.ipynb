# %%
# будем отображать графики прямо в jupyter'e
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt
#графики в svg выглядят более четкими
# %config InlineBackend.figure_format = 'svg' 

#увеличим дефолтный размер графиков
from pylab import rcParams
rcParams['figure.figsize'] = 8, 5
import pandas as pd
import numpy as np
from scipy. stats import pearsonr

# %%
dfAll = pd.read_csv('diamonds.csv')
dfAll=dfAll.dropna()
dfAll.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
dfAll.info()
df=dfAll.drop(columns = ['cut','color','clarity'],axis = 1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4999 entries, 0 to 4998
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    4999 non-null   float64
#  1   cut      4999 non-null   object
#  2   color    4999 non-null   object
#  3   clarity  4999 non-null   object
#  4   depth    4999 non-null   float64
#  5   table    4999 non-null   float64
#  6   price    4999 non-null   int64
#  7   x        4999 non-null   float64
#  8   y        4999 non-null   float64
#  9   z        4999 non-null   float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 390.7+ KB

# %%
df.mean()
# Out:
# carat       0.765607
# depth      61.855051
# table      57.635627
# price    2927.437487
# x           5.799676
# y           5.802136
# z           3.585833
# dtype: float64

# %%
df.std()
# Out:
# carat      0.204619
# depth      1.644960
# table      2.351286
# price    877.698902
# x          0.596703
# y          0.583709
# z          0.384570
# dtype: float64

# %%
df.hist(figsize=(20,10))
# Out:
# array([[<Axes: title={'center': 'carat'}>,
#         <Axes: title={'center': 'depth'}>,
#         <Axes: title={'center': 'table'}>],
#        [<Axes: title={'center': 'price'}>, <Axes: title={'center': 'x'}>,
#         <Axes: title={'center': 'y'}>],
#        [<Axes: title={'center': 'z'}>, <Axes: >, <Axes: >]], dtype=object)

# %%
column_names = df.columns

# Итерируемся по парам столбцов и вычисляем коэффициенты корреляции Пирсона
for i in range(len(column_names)):
    for j in range(i + 1, len(column_names)):
        column1_name = column_names[i]
        column2_name = column_names[j]
        
        corr_coefficient, p_value = pearsonr(df[column1_name], df[column2_name])
        
        print(f'Корреляция между {column1_name} и {column2_name}: {corr_coefficient}')
# Out:
# Корреляция между carat и depth: 0.10835628612003573
# Корреляция между carat и table: 0.20569321077174013
# Корреляция между carat и price: 0.8169693740537616
# Корреляция между carat и x: 0.9763575895910956
# Корреляция между carat и y: 0.9680519210718794
# Корреляция между carat и z: 0.9421184790963063
# Корреляция между depth и table: -0.2514611563354302
# Корреляция между depth и price: 0.021771148600389492
# Корреляция между depth и x: -0.023992189926311712
# Корреляция между depth и y: -0.033825568683450206
# Корреляция между depth и z: 0.22996489183551166
# Корреляция между table и price: 0.08890179251689535
# Корреляция между table и x: 0.19130828034872074
# Корреляция между table и y: 0.17675459241812636
# Корреляция между table и z: 0.10638817927900035
# Корреляция между price и x: 0.8764564069586265
# Корреляция между price и y: 0.8868655024959583
# Корреляция между price и z: 0.8395813074107652
# Корреляция между x и y: 0.9941079882548748
# ...

# %%
pd.plotting.scatter_matrix(df)
